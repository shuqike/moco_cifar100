# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/moco_cifar100/
# Out:
# /content/drive/Othercomputers/My Mac/moco_cifar100

# %%
# %pip install .
# Out:
# Processing /content/drive/Othercomputers/My Mac/moco_cifar100
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 46.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 25.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 8.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.2 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/shuqike/quinine.git
# Out:
# ...
#   Cloning https://github.com/shuqike/quinine.git to /tmp/pip-req-build-rpip45p8
#   Running command git clone --filter=blob:none --quiet https://github.com/shuqike/quinine.git /tmp/pip-req-build-rpip45p8
#   Resolved https://github.com/shuqike/quinine.git to commit 77b7195f6d0577e479eda70f54c4b0e3902d8165
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.8 MB/s eta 0:00:00
# ...
#   Created wheel for quinine: filename=quinine-0.3.0-py3-none-any.whl size=20796 sha256=b2a099dcfffa70de45f0d3bd50e2ab2717667fdfcd6c2609fdc08599233946c5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-837gs16u/wheels/4a/c8/cc/851a7103361e64cb16f5045167d8a5063bb57d5813504f8777
# Successfully built quinine
# ...

# %%
# %pip install opacus
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git
# Out:
# ...
#   Cloning https://github.com/awslabs/fast-differential-privacy.git to /tmp/pip-req-build-43aj05jg
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy.git /tmp/pip-req-build-43aj05jg
#   Resolved https://github.com/awslabs/fast-differential-privacy.git to commit 053a82df69e48698053570e90bc24cd8bba26daf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101667 sha256=4cfc0a81094d2bcc1e19ce74fcacdac3306d27c197a4cf300a9eeb91ce289dde
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bsvfcm78/wheels/09/8c/77/183c75a4d820b35303869508fe5f4b2b39556fe947c4983da8
# Successfully built fastDP
# ...

# %%
# !python3 differentially_private/baseline_train.py --config=configs/cifar100lpfull.yaml --log_dir=logs/moco3_1000ep_dplp5ft5_cifar100_lr_0.025_nm_0.3_mt_0_sd_1 --project_name=dplpftyes_cifar100 --group_name=dplpftyes_cifar100 --run_name moco3_1000ep_dp_lp5ft5_cifar100_lr_0.025_nm_0.3_mt_0_sd_1 --optimizer.args.lr=0.025 --full_ft_epoch=5 --no_wandb --seed 1 --privacy_engine.args.noise_multiplier=0.3 --model.args.checkpoint_path='cl/r-50-1000ep.pth.tar'
# Out:
# 01/06/2024 10:41:28:WARNING:Removed old run directory.
# ...
# 100% 169001437/169001437 [00:01<00:00, 100448433.87it/s]
# Extracting /u/scr/ananya//cifar100_dataset/cifar-100-python.tar.gz to /u/scr/ananya//cifar100_dataset
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# debug Parameter containing:
# tensor([[ 0.0144, -0.0149,  0.0088,  ..., -0.0095,  0.0177, -0.0002],
#         [ 0.0183, -0.0018,  0.0038,  ..., -0.0053, -0.0084, -0.0159],
#         [-0.0135, -0.0007, -0.0195,  ..., -0.0039,  0.0119, -0.0032],
#         ...,
# ...
